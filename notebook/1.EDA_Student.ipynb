# %% [markdown]
# # Problem statement
#
# This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course

# %% [markdown]
# ### Data
# Dataset source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977

# %%
import pandas as pd

# %%
df = pd.read_csv('data/StudentsPerformance.csv')

# %%
df.head()

# %%
#Check Null and Dtypes
df.info()

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### Insight
# - From above description of numerical data, all means are very close to each other between 66 and 68 --> Indicates a consistent difficulty level across all exams
# - All standard desviations are also close between (≈15) --> Indicating a consistent spread of scores
# - While there is a minimum score 0 for math, for writing minimum is much higher = 10 and for reading myet higher = 17

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Check the number of unique values of each column
df.nunique()

# %%
df.value_counts()

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
print('Categories in "gender" variable: ', end="")
print(df['gender'].unique())

print('Categories in "race ethnicity" variable: ', end="")
print(df['race/ethnicity'].unique())

print('Categories in "parental level of education" variable: ',end="")
print(df['parental level of education'].unique())

print('Categories in "lunch" variable: ',end="")
print(df['lunch'].unique())

print('Categories in "test preparation course" variable:  ',end="")
print(df['test preparation course'].unique())

# %%
# Define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype!='O']
categorical_feature = [feature for feature in df.columns if df[feature].dtype=='O']

print("I have {} numerical features: {}".format(len(numeric_features),numeric_features))
print('I have {} categorical feature: {}'.format(len(categorical_feature),categorical_feature))
# Out:
# I have 3 numerical features: ['math score', 'reading score', 'writing score']
# I have 5 categorical feature: ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %% [markdown]
# #### Feature engenering

# %%
df['total score']

# %%
import matplotlib.pyplot as plt

# Creacion el gráfico de dispersión
df.plot.scatter(x='reading score', y='writing score')

# Muestra del gráfico
plt.show()

# %%
import seaborn as sns

# Visualizacion de las 3 materias juntas
sns.boxplot(data=df[['math score', 'parental level of education']])
plt.show()

# %%
plt.figure(figsize=(12, 6)) # Hacemos el gráfico más ancho para que se lean los nombres
sns.boxplot(x='parental level of education', y='math score', data=df)
plt.show()

# %%
plt.figure(figsize=(12, 6)) # Hacemos el gráfico más ancho para que se lean los nombres
sns.boxplot(y='parental level of education', x='math score', data=df)
plt.show()
